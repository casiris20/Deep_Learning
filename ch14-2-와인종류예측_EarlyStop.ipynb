# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint,EarlyStopping

import pandas as pd
import numpy
import os
import tensorflow as tf

# seed 값 설정
numpy.random.seed(3)
tf.random.set_seed(3)

# %% [markdown]
# ## 1. 데이터 읽어오기

# %%
df_pre = pd.read_csv('dataset/wine.csv', header=None)
df = df_pre.sample(frac=0.15)
print(df_pre.info())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       6497 non-null   float64
#  1   1       6497 non-null   float64
#  2   2       6497 non-null   float64
#  3   3       6497 non-null   float64
#  4   4       6497 non-null   float64
#  5   5       6497 non-null   float64
#  6   6       6497 non-null   float64
#  7   7       6497 non-null   float64
#  8   8       6497 non-null   float64
#  9   9       6497 non-null   float64
#  10  10      6497 non-null   float64
#  11  11      6497 non-null   int64
#  12  12      6497 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 660.0 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 975 entries, 339 to 605
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       975 non-null    float64
#  1   1       975 non-null    float64
#  2   2       975 non-null    float64
#  3   3       975 non-null    float64
#  4   4       975 non-null    float64
#  5   5       975 non-null    float64
#  6   6       975 non-null    float64
#  7   7       975 non-null    float64
#  8   8       975 non-null    float64
#  9   9       975 non-null    float64
#  10  10      975 non-null    float64
#  11  11      975 non-null    int64
#  12  12      975 non-null    int64
# dtypes: float64(11), int64(2)
# memory usage: 106.6 KB

# %% [markdown]
# ## 2. 데이터 전처리

# %%
dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

# %% [markdown]
# ## 3. 모델 설계

# %%
model = Sequential()
model.add(Dense(30,  input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ## 4. 모델 컴파일

# %%
model.compile(loss='binary_crossentropy',
          optimizer='adam',
          metrics=['accuracy'])

# %% [markdown]
# ## 5. 학습

# %%
# 모델 저장 폴더 만들기
MODEL_DIR = './model/' ## MODEL_DIR : 모델 저장할 폴더 지정
if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

modelpath="./model/{epoch:02d}-{val_loss:.4f}.hdf5"
# epoch : 파일의 포맷 설정
#hdf5 : 파일 확장자


# 모델 업데이트 및 저장
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)
## checkpointer : 변수
## ModelCheckpoint : 함수


# 학습 자동 중단 설정
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=100) 
## patience : 상승하는 틱을 언제까지 놔둘 것인지

model.fit(X, Y, validation_split=0.2, epochs=3500, batch_size=500, verbose=0, 
          callbacks=[early_stopping_callback,checkpointer])

##callback : 
##checkpointer : loss 값을 계속 모니터링. patience 100 조건이 되면 학습을 종료시킴
# Out:
# Epoch 00001: val_loss improved from inf to 1.32295, saving model to ./model/01-1.3230.hdf5
#
# Epoch 00002: val_loss improved from 1.32295 to 0.95016, saving model to ./model/02-0.9502.hdf5
#
# Epoch 00003: val_loss improved from 0.95016 to 0.63020, saving model to ./model/03-0.6302.hdf5
#
# Epoch 00004: val_loss did not improve from 0.63020
#
# Epoch 00005: val_loss did not improve from 0.63020
#
# Epoch 00006: val_loss improved from 0.63020 to 0.51043, saving model to ./model/06-0.5104.hdf5
#
# Epoch 00007: val_loss improved from 0.51043 to 0.47466, saving model to ./model/07-0.4747.hdf5
#
# Epoch 00008: val_loss did not improve from 0.47466
#
# Epoch 00009: val_loss did not improve from 0.47466
#
# Epoch 00010: val_loss improved from 0.47466 to 0.45977, saving model to ./model/10-0.4598.hdf5
#
# Epoch 00011: val_loss improved from 0.45977 to 0.41665, saving model to ./model/11-0.4166.hdf5
#
# Epoch 00012: val_loss improved from 0.41665 to 0.37693, saving model to ./model/12-0.3769.hdf5
#
# Epoch 00013: val_loss improved from 0.37693 to 0.36434, saving model to ./model/13-0.3643.hdf5
#
# Epoch 00014: val_loss did not improve from 0.36434
#
# Epoch 00015: val_loss did not improve from 0.36434
#
# Epoch 00016: val_loss improved from 0.36434 to 0.33556, saving model to ./model/16-0.3356.hdf5
#
# Epoch 00017: val_loss improved from 0.33556 to 0.31682, saving model to ./model/17-0.3168.hdf5
#
# Epoch 00018: val_loss improved from 0.31682 to 0.31015, saving model to ./model/18-0.3101.hdf5
#
# Epoch 00019: val_loss improved from 0.31015 to 0.30486, saving model to ./model/19-0.3049.hdf5
#
# Epoch 00020: val_loss improved from 0.30486 to 0.29639, saving model to ./model/20-0.2964.hdf5
#
# Epoch 00021: val_loss improved from 0.29639 to 0.28682, saving model to ./model/21-0.2868.hdf5
#
# Epoch 00022: val_loss improved from 0.28682 to 0.28001, saving model to ./model/22-0.2800.hdf5
#
# Epoch 00023: val_loss improved from 0.28001 to 0.27680, saving model to ./model/23-0.2768.hdf5
#
# Epoch 00024: val_loss improved from 0.27680 to 0.27347, saving model to ./model/24-0.2735.hdf5
#
# Epoch 00025: val_loss improved from 0.27347 to 0.26751, saving model to ./model/25-0.2675.hdf5
#
# Epoch 00026: val_loss improved from 0.26751 to 0.26079, saving model to ./model/26-0.2608.hdf5
#
# Epoch 00027: val_loss improved from 0.26079 to 0.25578, saving model to ./model/27-0.2558.hdf5
#
# Epoch 00028: val_loss improved from 0.25578 to 0.25184, saving model to ./model/28-0.2518.hdf5
#
# Epoch 00029: val_loss improved from 0.25184 to 0.24835, saving model to ./model/29-0.2484.hdf5
#
# Epoch 00030: val_loss improved from 0.24835 to 0.24495, saving model to ./model/30-0.2450.hdf5
#
# Epoch 00031: val_loss improved from 0.24495 to 0.24215, saving model to ./model/31-0.2422.hdf5
#
# Epoch 00032: val_loss improved from 0.24215 to 0.24026, saving model to ./model/32-0.2403.hdf5
#
# Epoch 00033: val_loss improved from 0.24026 to 0.23883, saving model to ./model/33-0.2388.hdf5
#
# Epoch 00034: val_loss improved from 0.23883 to 0.23611, saving model to ./model/34-0.2361.hdf5
#
# Epoch 00035: val_loss improved from 0.23611 to 0.23268, saving model to ./model/35-0.2327.hdf5
#
# Epoch 00036: val_loss improved from 0.23268 to 0.22835, saving model to ./model/36-0.2284.hdf5
#
# Epoch 00037: val_loss improved from 0.22835 to 0.22386, saving model to ./model/37-0.2239.hdf5
#
# Epoch 00038: val_loss improved from 0.22386 to 0.22021, saving model to ./model/38-0.2202.hdf5
#
# Epoch 00039: val_loss improved from 0.22021 to 0.21703, saving model to ./model/39-0.2170.hdf5
#
# Epoch 00040: val_loss improved from 0.21703 to 0.21420, saving model to ./model/40-0.2142.hdf5
#
# Epoch 00041: val_loss improved from 0.21420 to 0.21128, saving model to ./model/41-0.2113.hdf5
#
# Epoch 00042: val_loss improved from 0.21128 to 0.20879, saving model to ./model/42-0.2088.hdf5
#
# Epoch 00043: val_loss improved from 0.20879 to 0.20645, saving model to ./model/43-0.2064.hdf5
#
# Epoch 00044: val_loss improved from 0.20645 to 0.20384, saving model to ./model/44-0.2038.hdf5
#
# Epoch 00045: val_loss improved from 0.20384 to 0.20188, saving model to ./model/45-0.2019.hdf5
#
# Epoch 00046: val_loss improved from 0.20188 to 0.20094, saving model to ./model/46-0.2009.hdf5
#
# Epoch 00047: val_loss improved from 0.20094 to 0.20041, saving model to ./model/47-0.2004.hdf5
#
# Epoch 00048: val_loss improved from 0.20041 to 0.19997, saving model to ./model/48-0.2000.hdf5
#
# Epoch 00049: val_loss improved from 0.19997 to 0.19935, saving model to ./model/49-0.1993.hdf5
#
# Epoch 00050: val_loss improved from 0.19935 to 0.19905, saving model to ./model/50-0.1990.hdf5
#
# Epoch 00051: val_loss improved from 0.19905 to 0.19880, saving model to ./model/51-0.1988.hdf5
#
# Epoch 00052: val_loss did not improve from 0.19880
#
# Epoch 00053: val_loss did not improve from 0.19880
#
# Epoch 00054: val_loss did not improve from 0.19880
#
# Epoch 00055: val_loss did not improve from 0.19880
#
# Epoch 00056: val_loss did not improve from 0.19880
#
# Epoch 00057: val_loss did not improve from 0.19880
#
# Epoch 00058: val_loss did not improve from 0.19880
#
# Epoch 00059: val_loss did not improve from 0.19880
#
# Epoch 00060: val_loss did not improve from 0.19880
#
# Epoch 00061: val_loss did not improve from 0.19880
#
# Epoch 00062: val_loss did not improve from 0.19880
#
# Epoch 00063: val_loss did not improve from 0.19880
#
# Epoch 00064: val_loss did not improve from 0.19880
#
# Epoch 00065: val_loss did not improve from 0.19880
#
# Epoch 00066: val_loss did not improve from 0.19880
#
# Epoch 00067: val_loss did not improve from 0.19880
#
# Epoch 00068: val_loss did not improve from 0.19880
#
# Epoch 00069: val_loss did not improve from 0.19880
#
# Epoch 00070: val_loss did not improve from 0.19880
#
# Epoch 00071: val_loss did not improve from 0.19880
#
# Epoch 00072: val_loss improved from 0.19880 to 0.19861, saving model to ./model/72-0.1986.hdf5
#
# Epoch 00073: val_loss improved from 0.19861 to 0.19605, saving model to ./model/73-0.1961.hdf5
#
# Epoch 00074: val_loss improved from 0.19605 to 0.19418, saving model to ./model/74-0.1942.hdf5
#
# Epoch 00075: val_loss improved from 0.19418 to 0.19279, saving model to ./model/75-0.1928.hdf5
#
# Epoch 00076: val_loss improved from 0.19279 to 0.19204, saving model to ./model/76-0.1920.hdf5
#
# Epoch 00077: val_loss improved from 0.19204 to 0.19180, saving model to ./model/77-0.1918.hdf5
#
# Epoch 00078: val_loss did not improve from 0.19180
#
# Epoch 00079: val_loss did not improve from 0.19180
#
# Epoch 00080: val_loss improved from 0.19180 to 0.19174, saving model to ./model/80-0.1917.hdf5
#
# Epoch 00081: val_loss improved from 0.19174 to 0.19166, saving model to ./model/81-0.1917.hdf5
#
# Epoch 00082: val_loss improved from 0.19166 to 0.19123, saving model to ./model/82-0.1912.hdf5
#
# Epoch 00083: val_loss improved from 0.19123 to 0.19084, saving model to ./model/83-0.1908.hdf5
#
# Epoch 00084: val_loss did not improve from 0.19084
#
# Epoch 00085: val_loss did not improve from 0.19084
#
# Epoch 00086: val_loss did not improve from 0.19084
#
# Epoch 00087: val_loss did not improve from 0.19084
#
# Epoch 00088: val_loss did not improve from 0.19084
#
# Epoch 00089: val_loss improved from 0.19084 to 0.18979, saving model to ./model/89-0.1898.hdf5
#
# Epoch 00090: val_loss improved from 0.18979 to 0.18930, saving model to ./model/90-0.1893.hdf5
#
# Epoch 00091: val_loss did not improve from 0.18930
#
# Epoch 00092: val_loss did not improve from 0.18930
#
# Epoch 00093: val_loss did not improve from 0.18930
#
# Epoch 00094: val_loss did not improve from 0.18930
#
# Epoch 00095: val_loss did not improve from 0.18930
#
# Epoch 00096: val_loss improved from 0.18930 to 0.18843, saving model to ./model/96-0.1884.hdf5
#
# Epoch 00097: val_loss improved from 0.18843 to 0.18778, saving model to ./model/97-0.1878.hdf5
#
# Epoch 00098: val_loss did not improve from 0.18778
#
# Epoch 00099: val_loss did not improve from 0.18778
#
# Epoch 00100: val_loss did not improve from 0.18778
#
# Epoch 00101: val_loss did not improve from 0.18778
#
# Epoch 00102: val_loss did not improve from 0.18778
#
# Epoch 00103: val_loss improved from 0.18778 to 0.18748, saving model to ./model/103-0.1875.hdf5
#
# Epoch 00104: val_loss improved from 0.18748 to 0.18674, saving model to ./model/104-0.1867.hdf5
#
# Epoch 00105: val_loss improved from 0.18674 to 0.18653, saving model to ./model/105-0.1865.hdf5
#
# Epoch 00106: val_loss improved from 0.18653 to 0.18640, saving model to ./model/106-0.1864.hdf5
#
# Epoch 00107: val_loss did not improve from 0.18640
#
# Epoch 00108: val_loss did not improve from 0.18640
#
# Epoch 00109: val_loss did not improve from 0.18640
#
# Epoch 00110: val_loss did not improve from 0.18640
#
# Epoch 00111: val_loss improved from 0.18640 to 0.18544, saving model to ./model/111-0.1854.hdf5
# Epoch 00112: val_loss did not improve from 0.18544
#
# Epoch 00113: val_loss did not improve from 0.18544
#
# Epoch 00114: val_loss did not improve from 0.18544
#
# Epoch 00115: val_loss improved from 0.18544 to 0.18538, saving model to ./model/115-0.1854.hdf5
#
# Epoch 00116: val_loss did not improve from 0.18538
#
# Epoch 00117: val_loss did not improve from 0.18538
#
# Epoch 00118: val_loss improved from 0.18538 to 0.18508, saving model to ./model/118-0.1851.hdf5
#
# Epoch 00119: val_loss improved from 0.18508 to 0.18431, saving model to ./model/119-0.1843.hdf5
#
# Epoch 00120: val_loss improved from 0.18431 to 0.18412, saving model to ./model/120-0.1841.hdf5
#
# Epoch 00121: val_loss improved from 0.18412 to 0.18328, saving model to ./model/121-0.1833.hdf5
#
# Epoch 00122: val_loss improved from 0.18328 to 0.18296, saving model to ./model/122-0.1830.hdf5
#
# Epoch 00123: val_loss did not improve from 0.18296
#
# Epoch 00124: val_loss did not improve from 0.18296
#
# Epoch 00125: val_loss did not improve from 0.18296
#
# Epoch 00126: val_loss did not improve from 0.18296
#
# Epoch 00127: val_loss improved from 0.18296 to 0.18265, saving model to ./model/127-0.1827.hdf5
#
# Epoch 00128: val_loss improved from 0.18265 to 0.18166, saving model to ./model/128-0.1817.hdf5
#
# Epoch 00129: val_loss improved from 0.18166 to 0.18144, saving model to ./model/129-0.1814.hdf5
#
# Epoch 00130: val_loss improved from 0.18144 to 0.18083, saving model to ./model/130-0.1808.hdf5
#
# Epoch 00131: val_loss improved from 0.18083 to 0.18043, saving model to ./model/131-0.1804.hdf5
#
# Epoch 00132: val_loss improved from 0.18043 to 0.18042, saving model to ./model/132-0.1804.hdf5
#
# Epoch 00133: val_loss did not improve from 0.18042
#
# Epoch 00134: val_loss did not improve from 0.18042
#
# Epoch 00135: val_loss did not improve from 0.18042
#
# Epoch 00136: val_loss did not improve from 0.18042
#
# Epoch 00137: val_loss did not improve from 0.18042
#
# Epoch 00138: val_loss did not improve from 0.18042
#
# Epoch 00139: val_loss did not improve from 0.18042
#
# Epoch 00140: val_loss improved from 0.18042 to 0.18011, saving model to ./model/140-0.1801.hdf5
#
# Epoch 00141: val_loss did not improve from 0.18011
#
# Epoch 00142: val_loss did not improve from 0.18011
#
# Epoch 00143: val_loss improved from 0.18011 to 0.17969, saving model to ./model/143-0.1797.hdf5
#
# Epoch 00144: val_loss improved from 0.17969 to 0.17914, saving model to ./model/144-0.1791.hdf5
#
# Epoch 00145: val_loss improved from 0.17914 to 0.17910, saving model to ./model/145-0.1791.hdf5
#
# Epoch 00146: val_loss did not improve from 0.17910
#
# Epoch 00147: val_loss did not improve from 0.17910
#
# Epoch 00148: val_loss did not improve from 0.17910
#
# Epoch 00149: val_loss did not improve from 0.17910
#
# Epoch 00150: val_loss improved from 0.17910 to 0.17855, saving model to ./model/150-0.1785.hdf5
#
# Epoch 00151: val_loss did not improve from 0.17855
#
# Epoch 00152: val_loss did not improve from 0.17855
#
# Epoch 00153: val_loss did not improve from 0.17855
#
# Epoch 00154: val_loss improved from 0.17855 to 0.17759, saving model to ./model/154-0.1776.hdf5
#
# Epoch 00155: val_loss improved from 0.17759 to 0.17709, saving model to ./model/155-0.1771.hdf5
#
# Epoch 00156: val_loss did not improve from 0.17709
#
# Epoch 00157: val_loss did not improve from 0.17709
#
# Epoch 00158: val_loss did not improve from 0.17709
#
# Epoch 00159: val_loss did not improve from 0.17709
#
# Epoch 00160: val_loss did not improve from 0.17709
#
# Epoch 00161: val_loss did not improve from 0.17709
#
# Epoch 00162: val_loss improved from 0.17709 to 0.17618, saving model to ./model/162-0.1762.hdf5
#
# Epoch 00163: val_loss did not improve from 0.17618
#
# Epoch 00164: val_loss did not improve from 0.17618
#
# Epoch 00165: val_loss did not improve from 0.17618
#
# Epoch 00166: val_loss did not improve from 0.17618
#
# Epoch 00167: val_loss did not improve from 0.17618
#
# Epoch 00168: val_loss improved from 0.17618 to 0.17589, saving model to ./model/168-0.1759.hdf5
#
# Epoch 00169: val_loss improved from 0.17589 to 0.17462, saving model to ./model/169-0.1746.hdf5
#
# Epoch 00170: val_loss improved from 0.17462 to 0.17458, saving model to ./model/170-0.1746.hdf5
#
# Epoch 00171: val_loss did not improve from 0.17458
#
# Epoch 00172: val_loss did not improve from 0.17458
#
# Epoch 00173: val_loss did not improve from 0.17458
#
# Epoch 00174: val_loss did not improve from 0.17458
#
# Epoch 00175: val_loss did not improve from 0.17458
#
# Epoch 00176: val_loss did not improve from 0.17458
#
# Epoch 00177: val_loss did not improve from 0.17458
#
# Epoch 00178: val_loss did not improve from 0.17458
#
# Epoch 00179: val_loss did not improve from 0.17458
#
# Epoch 00180: val_loss did not improve from 0.17458
#
# Epoch 00181: val_loss did not improve from 0.17458
#
# Epoch 00182: val_loss improved from 0.17458 to 0.17373, saving model to ./model/182-0.1737.hdf5
#
# Epoch 00183: val_loss improved from 0.17373 to 0.17277, saving model to ./model/183-0.1728.hdf5
#
# Epoch 00184: val_loss improved from 0.17277 to 0.17224, saving model to ./model/184-0.1722.hdf5
#
# Epoch 00185: val_loss did not improve from 0.17224
#
# Epoch 00186: val_loss did not improve from 0.17224
#
# Epoch 00187: val_loss did not improve from 0.17224
#
# Epoch 00188: val_loss did not improve from 0.17224
#
# Epoch 00189: val_loss did not improve from 0.17224
#
# Epoch 00190: val_loss did not improve from 0.17224
#
# Epoch 00191: val_loss did not improve from 0.17224
#
# Epoch 00192: val_loss did not improve from 0.17224
#
# Epoch 00193: val_loss did not improve from 0.17224
#
# Epoch 00194: val_loss did not improve from 0.17224
#
# Epoch 00195: val_loss did not improve from 0.17224
#
# Epoch 00196: val_loss did not improve from 0.17224
#
# Epoch 00197: val_loss improved from 0.17224 to 0.17200, saving model to ./model/197-0.1720.hdf5
#
# Epoch 00198: val_loss improved from 0.17200 to 0.17168, saving model to ./model/198-0.1717.hdf5
#
# Epoch 00199: val_loss did not improve from 0.17168
#
# Epoch 00200: val_loss did not improve from 0.17168
#
# Epoch 00201: val_loss did not improve from 0.17168
#
# Epoch 00202: val_loss did not improve from 0.17168
#
# Epoch 00203: val_loss did not improve from 0.17168
#
# Epoch 00204: val_loss did not improve from 0.17168
#
# Epoch 00205: val_loss did not improve from 0.17168
#
# Epoch 00206: val_loss improved from 0.17168 to 0.17139, saving model to ./model/206-0.1714.hdf5
#
# Epoch 00207: val_loss improved from 0.17139 to 0.17063, saving model to ./model/207-0.1706.hdf5
#
# Epoch 00208: val_loss did not improve from 0.17063
#
# Epoch 00209: val_loss did not improve from 0.17063
#
# Epoch 00210: val_loss improved from 0.17063 to 0.16996, saving model to ./model/210-0.1700.hdf5
#
# Epoch 00211: val_loss improved from 0.16996 to 0.16855, saving model to ./model/211-0.1686.hdf5
#
# Epoch 00212: val_loss improved from 0.16855 to 0.16817, saving model to ./model/212-0.1682.hdf5
#
# Epoch 00213: val_loss did not improve from 0.16817
#
# Epoch 00214: val_loss did not improve from 0.16817
#
# Epoch 00215: val_loss did not improve from 0.16817
#
# Epoch 00216: val_loss did not improve from 0.16817
#
# Epoch 00217: val_loss did not improve from 0.16817
#
# Epoch 00218: val_loss did not improve from 0.16817
#
# Epoch 00219: val_loss did not improve from 0.16817
#
# Epoch 00220: val_loss did not improve from 0.16817
#
# Epoch 00221: val_loss did not improve from 0.16817
#
# Epoch 00222: val_loss did not improve from 0.16817
#
# Epoch 00223: val_loss did not improve from 0.16817
#
# Epoch 00224: val_loss did not improve from 0.16817
#
# Epoch 00225: val_loss improved from 0.16817 to 0.16801, saving model to ./model/225-0.1680.hdf5
#
# Epoch 00226: val_loss improved from 0.16801 to 0.16679, saving model to ./model/226-0.1668.hdf5
#
# Epoch 00227: val_loss improved from 0.16679 to 0.16624, saving model to ./model/227-0.1662.hdf5
#
# Epoch 00228: val_loss did not improve from 0.16624
#
# Epoch 00229: val_loss did not improve from 0.16624
#
# Epoch 00230: val_loss did not improve from 0.16624
#
# Epoch 00231: val_loss did not improve from 0.16624
#
# Epoch 00232: val_loss did not improve from 0.16624
#
# Epoch 00233: val_loss did not improve from 0.16624
#
# Epoch 00234: val_loss did not improve from 0.16624
#
# Epoch 00235: val_loss did not improve from 0.16624
#
# Epoch 00236: val_loss did not improve from 0.16624
#
# Epoch 00237: val_loss did not improve from 0.16624
#
# Epoch 00238: val_loss did not improve from 0.16624
#
# Epoch 00239: val_loss improved from 0.16624 to 0.16460, saving model to ./model/239-0.1646.hdf5
# Epoch 00240: val_loss did not improve from 0.16460
#
# Epoch 00241: val_loss did not improve from 0.16460
#
# Epoch 00242: val_loss did not improve from 0.16460
#
# Epoch 00243: val_loss did not improve from 0.16460
#
# Epoch 00244: val_loss did not improve from 0.16460
#
# Epoch 00245: val_loss improved from 0.16460 to 0.16378, saving model to ./model/245-0.1638.hdf5
#
# Epoch 00246: val_loss did not improve from 0.16378
#
# Epoch 00247: val_loss did not improve from 0.16378
#
# Epoch 00248: val_loss did not improve from 0.16378
#
# Epoch 00249: val_loss did not improve from 0.16378
#
# Epoch 00250: val_loss did not improve from 0.16378
#
# Epoch 00251: val_loss did not improve from 0.16378
#
# Epoch 00252: val_loss did not improve from 0.16378
#
# Epoch 00253: val_loss did not improve from 0.16378
#
# Epoch 00254: val_loss did not improve from 0.16378
#
# Epoch 00255: val_loss did not improve from 0.16378
#
# Epoch 00256: val_loss did not improve from 0.16378
#
# Epoch 00257: val_loss did not improve from 0.16378
#
# Epoch 00258: val_loss did not improve from 0.16378
#
# Epoch 00259: val_loss did not improve from 0.16378
#
# Epoch 00260: val_loss improved from 0.16378 to 0.16324, saving model to ./model/260-0.1632.hdf5
#
# Epoch 00261: val_loss improved from 0.16324 to 0.16272, saving model to ./model/261-0.1627.hdf5
#
# Epoch 00262: val_loss did not improve from 0.16272
#
# Epoch 00263: val_loss did not improve from 0.16272
#
# Epoch 00264: val_loss did not improve from 0.16272
#
# Epoch 00265: val_loss did not improve from 0.16272
#
# Epoch 00266: val_loss improved from 0.16272 to 0.16163, saving model to ./model/266-0.1616.hdf5
#
# Epoch 00267: val_loss improved from 0.16163 to 0.16129, saving model to ./model/267-0.1613.hdf5
#
# Epoch 00268: val_loss did not improve from 0.16129
#
# Epoch 00269: val_loss did not improve from 0.16129
#
# Epoch 00270: val_loss did not improve from 0.16129
#
# Epoch 00271: val_loss did not improve from 0.16129
#
# Epoch 00272: val_loss did not improve from 0.16129
#
# Epoch 00273: val_loss improved from 0.16129 to 0.15981, saving model to ./model/273-0.1598.hdf5
#
# Epoch 00274: val_loss improved from 0.15981 to 0.15923, saving model to ./model/274-0.1592.hdf5
#
# Epoch 00275: val_loss did not improve from 0.15923
#
# Epoch 00276: val_loss did not improve from 0.15923
#
# Epoch 00277: val_loss did not improve from 0.15923
#
# Epoch 00278: val_loss did not improve from 0.15923
#
# Epoch 00279: val_loss did not improve from 0.15923
#
# Epoch 00280: val_loss did not improve from 0.15923
#
# Epoch 00281: val_loss did not improve from 0.15923
#
# Epoch 00282: val_loss did not improve from 0.15923
#
# Epoch 00283: val_loss did not improve from 0.15923
#
# Epoch 00284: val_loss did not improve from 0.15923
#
# Epoch 00285: val_loss improved from 0.15923 to 0.15825, saving model to ./model/285-0.1582.hdf5
#
# Epoch 00286: val_loss did not improve from 0.15825
#
# Epoch 00287: val_loss did not improve from 0.15825
#
# Epoch 00288: val_loss did not improve from 0.15825
#
# Epoch 00289: val_loss did not improve from 0.15825
#
# Epoch 00290: val_loss did not improve from 0.15825
#
# Epoch 00291: val_loss improved from 0.15825 to 0.15784, saving model to ./model/291-0.1578.hdf5
#
# Epoch 00292: val_loss did not improve from 0.15784
#
# Epoch 00293: val_loss did not improve from 0.15784
#
# Epoch 00294: val_loss did not improve from 0.15784
#
# Epoch 00295: val_loss did not improve from 0.15784
#
# Epoch 00296: val_loss did not improve from 0.15784
#
# Epoch 00297: val_loss improved from 0.15784 to 0.15771, saving model to ./model/297-0.1577.hdf5
#
# Epoch 00298: val_loss did not improve from 0.15771
#
# Epoch 00299: val_loss did not improve from 0.15771
#
# Epoch 00300: val_loss did not improve from 0.15771
#
# Epoch 00301: val_loss did not improve from 0.15771
#
# Epoch 00302: val_loss did not improve from 0.15771
#
# Epoch 00303: val_loss did not improve from 0.15771
#
# Epoch 00304: val_loss did not improve from 0.15771
#
# Epoch 00305: val_loss did not improve from 0.15771
#
# Epoch 00306: val_loss did not improve from 0.15771
#
# Epoch 00307: val_loss did not improve from 0.15771
#
# Epoch 00308: val_loss improved from 0.15771 to 0.15598, saving model to ./model/308-0.1560.hdf5
#
# Epoch 00309: val_loss improved from 0.15598 to 0.15535, saving model to ./model/309-0.1554.hdf5
#
# Epoch 00310: val_loss did not improve from 0.15535
#
# Epoch 00311: val_loss did not improve from 0.15535
#
# Epoch 00312: val_loss did not improve from 0.15535
#
# Epoch 00313: val_loss did not improve from 0.15535
#
# Epoch 00314: val_loss did not improve from 0.15535
#
# Epoch 00315: val_loss did not improve from 0.15535
#
# Epoch 00316: val_loss did not improve from 0.15535
#
# Epoch 00317: val_loss did not improve from 0.15535
#
# Epoch 00318: val_loss did not improve from 0.15535
#
# Epoch 00319: val_loss did not improve from 0.15535
#
# Epoch 00320: val_loss improved from 0.15535 to 0.15422, saving model to ./model/320-0.1542.hdf5
#
# Epoch 00321: val_loss did not improve from 0.15422
#
# Epoch 00322: val_loss did not improve from 0.15422
#
# Epoch 00323: val_loss did not improve from 0.15422
#
# Epoch 00324: val_loss did not improve from 0.15422
#
# Epoch 00325: val_loss did not improve from 0.15422
#
# Epoch 00326: val_loss did not improve from 0.15422
#
# Epoch 00327: val_loss did not improve from 0.15422
#
# Epoch 00328: val_loss did not improve from 0.15422
#
# Epoch 00329: val_loss did not improve from 0.15422
#
# Epoch 00330: val_loss did not improve from 0.15422
#
# Epoch 00331: val_loss did not improve from 0.15422
#
# Epoch 00332: val_loss did not improve from 0.15422
#
# Epoch 00333: val_loss improved from 0.15422 to 0.15411, saving model to ./model/333-0.1541.hdf5
#
# Epoch 00334: val_loss improved from 0.15411 to 0.15376, saving model to ./model/334-0.1538.hdf5
#
# Epoch 00335: val_loss did not improve from 0.15376
#
# Epoch 00336: val_loss did not improve from 0.15376
#
# Epoch 00337: val_loss did not improve from 0.15376
#
# Epoch 00338: val_loss improved from 0.15376 to 0.15281, saving model to ./model/338-0.1528.hdf5
#
# Epoch 00339: val_loss improved from 0.15281 to 0.15234, saving model to ./model/339-0.1523.hdf5
#
# Epoch 00340: val_loss did not improve from 0.15234
#
# Epoch 00341: val_loss did not improve from 0.15234
#
# Epoch 00342: val_loss did not improve from 0.15234
#
# Epoch 00343: val_loss did not improve from 0.15234
#
# Epoch 00344: val_loss improved from 0.15234 to 0.15141, saving model to ./model/344-0.1514.hdf5
#
# Epoch 00345: val_loss did not improve from 0.15141
#
# Epoch 00346: val_loss did not improve from 0.15141
#
# Epoch 00347: val_loss did not improve from 0.15141
#
# Epoch 00348: val_loss improved from 0.15141 to 0.15121, saving model to ./model/348-0.1512.hdf5
#
# Epoch 00349: val_loss improved from 0.15121 to 0.15097, saving model to ./model/349-0.1510.hdf5
#
# Epoch 00350: val_loss did not improve from 0.15097
#
# Epoch 00351: val_loss did not improve from 0.15097
#
# Epoch 00352: val_loss did not improve from 0.15097
#
# Epoch 00353: val_loss did not improve from 0.15097
#
# Epoch 00354: val_loss improved from 0.15097 to 0.15055, saving model to ./model/354-0.1506.hdf5
#
# Epoch 00355: val_loss did not improve from 0.15055
#
# Epoch 00356: val_loss did not improve from 0.15055
#
# Epoch 00357: val_loss did not improve from 0.15055
#
# Epoch 00358: val_loss did not improve from 0.15055
#
# Epoch 00359: val_loss improved from 0.15055 to 0.15017, saving model to ./model/359-0.1502.hdf5
#
# Epoch 00360: val_loss did not improve from 0.15017
#
# Epoch 00361: val_loss did not improve from 0.15017
#
# Epoch 00362: val_loss did not improve from 0.15017
#
# Epoch 00363: val_loss did not improve from 0.15017
#
# Epoch 00364: val_loss improved from 0.15017 to 0.14876, saving model to ./model/364-0.1488.hdf5
#
# Epoch 00365: val_loss improved from 0.14876 to 0.14835, saving model to ./model/365-0.1484.hdf5
#
# Epoch 00366: val_loss did not improve from 0.14835
#
# Epoch 00367: val_loss did not improve from 0.14835
#
# Epoch 00368: val_loss did not improve from 0.14835
#
# Epoch 00369: val_loss did not improve from 0.14835
#
# Epoch 00370: val_loss improved from 0.14835 to 0.14743, saving model to ./model/370-0.1474.hdf5
#
# Epoch 00371: val_loss did not improve from 0.14743
#
# Epoch 00372: val_loss did not improve from 0.14743
#
# Epoch 00373: val_loss did not improve from 0.14743
#
# Epoch 00374: val_loss improved from 0.14743 to 0.14656, saving model to ./model/374-0.1466.hdf5
#
# Epoch 00375: val_loss did not improve from 0.14656
#
# Epoch 00376: val_loss did not improve from 0.14656
#
# Epoch 00377: val_loss did not improve from 0.14656
#
# Epoch 00378: val_loss improved from 0.14656 to 0.14415, saving model to ./model/378-0.1442.hdf5
#
# Epoch 00379: val_loss improved from 0.14415 to 0.14291, saving model to ./model/379-0.1429.hdf5
# Epoch 00380: val_loss did not improve from 0.14291
#
# Epoch 00381: val_loss did not improve from 0.14291
#
# Epoch 00382: val_loss did not improve from 0.14291
#
# Epoch 00383: val_loss did not improve from 0.14291
#
# Epoch 00384: val_loss improved from 0.14291 to 0.14258, saving model to ./model/384-0.1426.hdf5
#
# Epoch 00385: val_loss did not improve from 0.14258
#
# Epoch 00386: val_loss did not improve from 0.14258
#
# Epoch 00387: val_loss did not improve from 0.14258
#
# Epoch 00388: val_loss did not improve from 0.14258
#
# Epoch 00389: val_loss improved from 0.14258 to 0.14206, saving model to ./model/389-0.1421.hdf5
#
# Epoch 00390: val_loss did not improve from 0.14206
#
# Epoch 00391: val_loss did not improve from 0.14206
#
# Epoch 00392: val_loss did not improve from 0.14206
#
# Epoch 00393: val_loss did not improve from 0.14206
#
# Epoch 00394: val_loss did not improve from 0.14206
#
# Epoch 00395: val_loss did not improve from 0.14206
#
# Epoch 00396: val_loss did not improve from 0.14206
#
# Epoch 00397: val_loss did not improve from 0.14206
#
# Epoch 00398: val_loss did not improve from 0.14206
#
# Epoch 00399: val_loss did not improve from 0.14206
#
# Epoch 00400: val_loss did not improve from 0.14206
#
# Epoch 00401: val_loss did not improve from 0.14206
#
# Epoch 00402: val_loss did not improve from 0.14206
#
# Epoch 00403: val_loss improved from 0.14206 to 0.14170, saving model to ./model/403-0.1417.hdf5
#
# Epoch 00404: val_loss improved from 0.14170 to 0.14155, saving model to ./model/404-0.1416.hdf5
#
# Epoch 00405: val_loss did not improve from 0.14155
#
# Epoch 00406: val_loss did not improve from 0.14155
#
# Epoch 00407: val_loss did not improve from 0.14155
#
# Epoch 00408: val_loss did not improve from 0.14155
#
# Epoch 00409: val_loss did not improve from 0.14155
#
# Epoch 00410: val_loss did not improve from 0.14155
#
# Epoch 00411: val_loss did not improve from 0.14155
#
# Epoch 00412: val_loss did not improve from 0.14155
#
# Epoch 00413: val_loss improved from 0.14155 to 0.13984, saving model to ./model/413-0.1398.hdf5
#
# Epoch 00414: val_loss did not improve from 0.13984
#
# Epoch 00415: val_loss did not improve from 0.13984
#
# Epoch 00416: val_loss did not improve from 0.13984
#
# Epoch 00417: val_loss did not improve from 0.13984
#
# Epoch 00418: val_loss improved from 0.13984 to 0.13864, saving model to ./model/418-0.1386.hdf5
#
# Epoch 00419: val_loss did not improve from 0.13864
#
# Epoch 00420: val_loss did not improve from 0.13864
#
# Epoch 00421: val_loss did not improve from 0.13864
#
# Epoch 00422: val_loss did not improve from 0.13864
#
# Epoch 00423: val_loss did not improve from 0.13864
#
# Epoch 00424: val_loss did not improve from 0.13864
#
# Epoch 00425: val_loss did not improve from 0.13864
#
# Epoch 00426: val_loss did not improve from 0.13864
#
# Epoch 00427: val_loss did not improve from 0.13864
#
# Epoch 00428: val_loss improved from 0.13864 to 0.13839, saving model to ./model/428-0.1384.hdf5
#
# Epoch 00429: val_loss improved from 0.13839 to 0.13834, saving model to ./model/429-0.1383.hdf5
#
# Epoch 00430: val_loss did not improve from 0.13834
#
# Epoch 00431: val_loss did not improve from 0.13834
#
# Epoch 00432: val_loss did not improve from 0.13834
#
# Epoch 00433: val_loss improved from 0.13834 to 0.13776, saving model to ./model/433-0.1378.hdf5
#
# Epoch 00434: val_loss improved from 0.13776 to 0.13737, saving model to ./model/434-0.1374.hdf5
#
# Epoch 00435: val_loss did not improve from 0.13737
#
# Epoch 00436: val_loss did not improve from 0.13737
#
# Epoch 00437: val_loss did not improve from 0.13737
#
# Epoch 00438: val_loss did not improve from 0.13737
#
# Epoch 00439: val_loss did not improve from 0.13737
#
# Epoch 00440: val_loss did not improve from 0.13737
#
# Epoch 00441: val_loss did not improve from 0.13737
#
# Epoch 00442: val_loss did not improve from 0.13737
#
# Epoch 00443: val_loss did not improve from 0.13737
#
# Epoch 00444: val_loss did not improve from 0.13737
#
# Epoch 00445: val_loss did not improve from 0.13737
#
# Epoch 00446: val_loss did not improve from 0.13737
#
# Epoch 00447: val_loss improved from 0.13737 to 0.13634, saving model to ./model/447-0.1363.hdf5
#
# Epoch 00448: val_loss did not improve from 0.13634
#
# Epoch 00449: val_loss did not improve from 0.13634
#
# Epoch 00450: val_loss did not improve from 0.13634
#
# Epoch 00451: val_loss improved from 0.13634 to 0.13481, saving model to ./model/451-0.1348.hdf5
#
# Epoch 00452: val_loss improved from 0.13481 to 0.13468, saving model to ./model/452-0.1347.hdf5
#
# Epoch 00453: val_loss did not improve from 0.13468
#
# Epoch 00454: val_loss did not improve from 0.13468
#
# Epoch 00455: val_loss did not improve from 0.13468
#
# Epoch 00456: val_loss did not improve from 0.13468
#
# Epoch 00457: val_loss did not improve from 0.13468
#
# Epoch 00458: val_loss did not improve from 0.13468
#
# Epoch 00459: val_loss did not improve from 0.13468
#
# Epoch 00460: val_loss improved from 0.13468 to 0.13442, saving model to ./model/460-0.1344.hdf5
#
# Epoch 00461: val_loss did not improve from 0.13442
#
# Epoch 00462: val_loss did not improve from 0.13442
#
# Epoch 00463: val_loss did not improve from 0.13442
#
# Epoch 00464: val_loss did not improve from 0.13442
#
# Epoch 00465: val_loss did not improve from 0.13442
#
# Epoch 00466: val_loss improved from 0.13442 to 0.13426, saving model to ./model/466-0.1343.hdf5
#
# Epoch 00467: val_loss did not improve from 0.13426
#
# Epoch 00468: val_loss did not improve from 0.13426
#
# Epoch 00469: val_loss did not improve from 0.13426
#
# Epoch 00470: val_loss did not improve from 0.13426
#
# Epoch 00471: val_loss improved from 0.13426 to 0.13341, saving model to ./model/471-0.1334.hdf5
#
# Epoch 00472: val_loss did not improve from 0.13341
#
# Epoch 00473: val_loss did not improve from 0.13341
#
# Epoch 00474: val_loss did not improve from 0.13341
#
# Epoch 00475: val_loss did not improve from 0.13341
#
# Epoch 00476: val_loss did not improve from 0.13341
#
# Epoch 00477: val_loss did not improve from 0.13341
#
# Epoch 00478: val_loss improved from 0.13341 to 0.13217, saving model to ./model/478-0.1322.hdf5
#
# Epoch 00479: val_loss improved from 0.13217 to 0.13168, saving model to ./model/479-0.1317.hdf5
#
# Epoch 00480: val_loss did not improve from 0.13168
#
# Epoch 00481: val_loss did not improve from 0.13168
#
# Epoch 00482: val_loss did not improve from 0.13168
#
# Epoch 00483: val_loss did not improve from 0.13168
#
# Epoch 00484: val_loss improved from 0.13168 to 0.13156, saving model to ./model/484-0.1316.hdf5
#
# Epoch 00485: val_loss did not improve from 0.13156
#
# Epoch 00486: val_loss did not improve from 0.13156
#
# Epoch 00487: val_loss improved from 0.13156 to 0.13121, saving model to ./model/487-0.1312.hdf5
#
# Epoch 00488: val_loss improved from 0.13121 to 0.13106, saving model to ./model/488-0.1311.hdf5
#
# Epoch 00489: val_loss did not improve from 0.13106
#
# Epoch 00490: val_loss did not improve from 0.13106
#
# Epoch 00491: val_loss did not improve from 0.13106
#
# Epoch 00492: val_loss did not improve from 0.13106
#
# Epoch 00493: val_loss did not improve from 0.13106
#
# Epoch 00494: val_loss did not improve from 0.13106
#
# Epoch 00495: val_loss improved from 0.13106 to 0.13033, saving model to ./model/495-0.1303.hdf5
#
# Epoch 00496: val_loss improved from 0.13033 to 0.12908, saving model to ./model/496-0.1291.hdf5
#
# Epoch 00497: val_loss did not improve from 0.12908
#
# Epoch 00498: val_loss did not improve from 0.12908
#
# Epoch 00499: val_loss did not improve from 0.12908
#
# Epoch 00500: val_loss did not improve from 0.12908
#
# Epoch 00501: val_loss improved from 0.12908 to 0.12897, saving model to ./model/501-0.1290.hdf5
#
# Epoch 00502: val_loss did not improve from 0.12897
#
# Epoch 00503: val_loss did not improve from 0.12897
#
# Epoch 00504: val_loss did not improve from 0.12897
#
# Epoch 00505: val_loss improved from 0.12897 to 0.12872, saving model to ./model/505-0.1287.hdf5
#
# Epoch 00506: val_loss did not improve from 0.12872
#
# Epoch 00507: val_loss did not improve from 0.12872
#
# Epoch 00508: val_loss did not improve from 0.12872
#
# Epoch 00509: val_loss did not improve from 0.12872
#
# Epoch 00510: val_loss improved from 0.12872 to 0.12866, saving model to ./model/510-0.1287.hdf5
#
# Epoch 00511: val_loss improved from 0.12866 to 0.12810, saving model to ./model/511-0.1281.hdf5
#
# Epoch 00512: val_loss did not improve from 0.12810
#
# Epoch 00513: val_loss did not improve from 0.12810
#
# Epoch 00514: val_loss improved from 0.12810 to 0.12657, saving model to ./model/514-0.1266.hdf5
# Epoch 00515: val_loss improved from 0.12657 to 0.12609, saving model to ./model/515-0.1261.hdf5
#
# Epoch 00516: val_loss did not improve from 0.12609
#
# Epoch 00517: val_loss did not improve from 0.12609
#
# Epoch 00518: val_loss did not improve from 0.12609
#
# Epoch 00519: val_loss did not improve from 0.12609
#
# Epoch 00520: val_loss did not improve from 0.12609
#
# Epoch 00521: val_loss did not improve from 0.12609
#
# Epoch 00522: val_loss did not improve from 0.12609
#
# Epoch 00523: val_loss did not improve from 0.12609
#
# Epoch 00524: val_loss did not improve from 0.12609
#
# Epoch 00525: val_loss did not improve from 0.12609
#
# Epoch 00526: val_loss did not improve from 0.12609
#
# Epoch 00527: val_loss did not improve from 0.12609
#
# Epoch 00528: val_loss did not improve from 0.12609
#
# Epoch 00529: val_loss did not improve from 0.12609
#
# Epoch 00530: val_loss did not improve from 0.12609
#
# Epoch 00531: val_loss did not improve from 0.12609
#
# Epoch 00532: val_loss did not improve from 0.12609
#
# Epoch 00533: val_loss did not improve from 0.12609
#
# Epoch 00534: val_loss did not improve from 0.12609
#
# Epoch 00535: val_loss did not improve from 0.12609
#
# Epoch 00536: val_loss improved from 0.12609 to 0.12535, saving model to ./model/536-0.1253.hdf5
#
# Epoch 00537: val_loss improved from 0.12535 to 0.12493, saving model to ./model/537-0.1249.hdf5
#
# Epoch 00538: val_loss did not improve from 0.12493
#
# Epoch 00539: val_loss did not improve from 0.12493
#
# Epoch 00540: val_loss did not improve from 0.12493
#
# Epoch 00541: val_loss improved from 0.12493 to 0.12385, saving model to ./model/541-0.1238.hdf5
#
# Epoch 00542: val_loss did not improve from 0.12385
#
# Epoch 00543: val_loss did not improve from 0.12385
#
# Epoch 00544: val_loss did not improve from 0.12385
#
# Epoch 00545: val_loss improved from 0.12385 to 0.12369, saving model to ./model/545-0.1237.hdf5
#
# Epoch 00546: val_loss improved from 0.12369 to 0.12340, saving model to ./model/546-0.1234.hdf5
#
# Epoch 00547: val_loss did not improve from 0.12340
#
# Epoch 00548: val_loss did not improve from 0.12340
#
# Epoch 00549: val_loss did not improve from 0.12340
#
# Epoch 00550: val_loss improved from 0.12340 to 0.12300, saving model to ./model/550-0.1230.hdf5
#
# Epoch 00551: val_loss did not improve from 0.12300
#
# Epoch 00552: val_loss did not improve from 0.12300
#
# Epoch 00553: val_loss did not improve from 0.12300
#
# Epoch 00554: val_loss improved from 0.12300 to 0.12269, saving model to ./model/554-0.1227.hdf5
#
# Epoch 00555: val_loss did not improve from 0.12269
#
# Epoch 00556: val_loss did not improve from 0.12269
#
# Epoch 00557: val_loss did not improve from 0.12269
#
# Epoch 00558: val_loss did not improve from 0.12269
#
# Epoch 00559: val_loss improved from 0.12269 to 0.12234, saving model to ./model/559-0.1223.hdf5
#
# Epoch 00560: val_loss did not improve from 0.12234
#
# Epoch 00561: val_loss did not improve from 0.12234
#
# Epoch 00562: val_loss did not improve from 0.12234
#
# Epoch 00563: val_loss improved from 0.12234 to 0.12122, saving model to ./model/563-0.1212.hdf5
#
# Epoch 00564: val_loss improved from 0.12122 to 0.12103, saving model to ./model/564-0.1210.hdf5
#
# Epoch 00565: val_loss did not improve from 0.12103
#
# Epoch 00566: val_loss did not improve from 0.12103
#
# Epoch 00567: val_loss improved from 0.12103 to 0.12050, saving model to ./model/567-0.1205.hdf5
#
# Epoch 00568: val_loss improved from 0.12050 to 0.12013, saving model to ./model/568-0.1201.hdf5
#
# Epoch 00569: val_loss did not improve from 0.12013
#
# Epoch 00570: val_loss did not improve from 0.12013
#
# Epoch 00571: val_loss did not improve from 0.12013
#
# Epoch 00572: val_loss did not improve from 0.12013
#
# Epoch 00573: val_loss did not improve from 0.12013
#
# Epoch 00574: val_loss did not improve from 0.12013
#
# Epoch 00575: val_loss did not improve from 0.12013
#
# Epoch 00576: val_loss did not improve from 0.12013
#
# Epoch 00577: val_loss did not improve from 0.12013
#
# Epoch 00578: val_loss did not improve from 0.12013
#
# Epoch 00579: val_loss improved from 0.12013 to 0.12002, saving model to ./model/579-0.1200.hdf5
#
# Epoch 00580: val_loss did not improve from 0.12002
#
# Epoch 00581: val_loss did not improve from 0.12002
#
# Epoch 00582: val_loss did not improve from 0.12002
#
# Epoch 00583: val_loss did not improve from 0.12002
#
# Epoch 00584: val_loss did not improve from 0.12002
#
# Epoch 00585: val_loss did not improve from 0.12002
#
# Epoch 00586: val_loss did not improve from 0.12002
#
# Epoch 00587: val_loss did not improve from 0.12002
#
# Epoch 00588: val_loss improved from 0.12002 to 0.11958, saving model to ./model/588-0.1196.hdf5
#
# Epoch 00589: val_loss did not improve from 0.11958
#
# Epoch 00590: val_loss did not improve from 0.11958
#
# Epoch 00591: val_loss did not improve from 0.11958
#
# Epoch 00592: val_loss did not improve from 0.11958
#
# Epoch 00593: val_loss did not improve from 0.11958
#
# Epoch 00594: val_loss did not improve from 0.11958
#
# Epoch 00595: val_loss improved from 0.11958 to 0.11879, saving model to ./model/595-0.1188.hdf5
#
# Epoch 00596: val_loss did not improve from 0.11879
#
# Epoch 00597: val_loss did not improve from 0.11879
#
# Epoch 00598: val_loss did not improve from 0.11879
#
# Epoch 00599: val_loss did not improve from 0.11879
#
# Epoch 00600: val_loss improved from 0.11879 to 0.11857, saving model to ./model/600-0.1186.hdf5
#
# Epoch 00601: val_loss improved from 0.11857 to 0.11745, saving model to ./model/601-0.1175.hdf5
#
# Epoch 00602: val_loss did not improve from 0.11745
#
# Epoch 00603: val_loss did not improve from 0.11745
#
# Epoch 00604: val_loss did not improve from 0.11745
#
# Epoch 00605: val_loss did not improve from 0.11745
#
# Epoch 00606: val_loss did not improve from 0.11745
#
# Epoch 00607: val_loss did not improve from 0.11745
#
# Epoch 00608: val_loss did not improve from 0.11745
#
# Epoch 00609: val_loss did not improve from 0.11745
#
# Epoch 00610: val_loss did not improve from 0.11745
#
# Epoch 00611: val_loss did not improve from 0.11745
#
# Epoch 00612: val_loss did not improve from 0.11745
#
# Epoch 00613: val_loss did not improve from 0.11745
#
# Epoch 00614: val_loss did not improve from 0.11745
#
# Epoch 00615: val_loss did not improve from 0.11745
#
# Epoch 00616: val_loss did not improve from 0.11745
#
# Epoch 00617: val_loss did not improve from 0.11745
#
# Epoch 00618: val_loss did not improve from 0.11745
#
# Epoch 00619: val_loss did not improve from 0.11745
#
# Epoch 00620: val_loss did not improve from 0.11745
#
# Epoch 00621: val_loss did not improve from 0.11745
#
# Epoch 00622: val_loss did not improve from 0.11745
#
# Epoch 00623: val_loss improved from 0.11745 to 0.11745, saving model to ./model/623-0.1174.hdf5
#
# Epoch 00624: val_loss improved from 0.11745 to 0.11680, saving model to ./model/624-0.1168.hdf5
#
# Epoch 00625: val_loss did not improve from 0.11680
#
# Epoch 00626: val_loss did not improve from 0.11680
#
# Epoch 00627: val_loss did not improve from 0.11680
#
# Epoch 00628: val_loss did not improve from 0.11680
#
# Epoch 00629: val_loss did not improve from 0.11680
#
# Epoch 00630: val_loss did not improve from 0.11680
#
# Epoch 00631: val_loss improved from 0.11680 to 0.11644, saving model to ./model/631-0.1164.hdf5
#
# Epoch 00632: val_loss improved from 0.11644 to 0.11507, saving model to ./model/632-0.1151.hdf5
#
# Epoch 00633: val_loss did not improve from 0.11507
#
# Epoch 00634: val_loss did not improve from 0.11507
#
# Epoch 00635: val_loss did not improve from 0.11507
#
# Epoch 00636: val_loss did not improve from 0.11507
#
# Epoch 00637: val_loss did not improve from 0.11507
#
# Epoch 00638: val_loss did not improve from 0.11507
#
# Epoch 00639: val_loss did not improve from 0.11507
#
# Epoch 00640: val_loss improved from 0.11507 to 0.11396, saving model to ./model/640-0.1140.hdf5
#
# Epoch 00641: val_loss did not improve from 0.11396
#
# Epoch 00642: val_loss did not improve from 0.11396
#
# Epoch 00643: val_loss did not improve from 0.11396
#
# Epoch 00644: val_loss did not improve from 0.11396
#
# Epoch 00645: val_loss did not improve from 0.11396
#
# Epoch 00646: val_loss did not improve from 0.11396
#
# Epoch 00647: val_loss did not improve from 0.11396
#
# Epoch 00648: val_loss did not improve from 0.11396
#
# Epoch 00649: val_loss did not improve from 0.11396
#
# Epoch 00650: val_loss did not improve from 0.11396
#
# Epoch 00651: val_loss did not improve from 0.11396
#
# Epoch 00652: val_loss did not improve from 0.11396
#
# Epoch 00653: val_loss did not improve from 0.11396
#
# Epoch 00654: val_loss did not improve from 0.11396
#
# Epoch 00655: val_loss did not improve from 0.11396
#
# Epoch 00656: val_loss did not improve from 0.11396
# Epoch 00657: val_loss did not improve from 0.11396
#
# Epoch 00658: val_loss did not improve from 0.11396
#
# Epoch 00659: val_loss did not improve from 0.11396
#
# Epoch 00660: val_loss did not improve from 0.11396
#
# Epoch 00661: val_loss did not improve from 0.11396
#
# Epoch 00662: val_loss did not improve from 0.11396
#
# Epoch 00663: val_loss did not improve from 0.11396
#
# Epoch 00664: val_loss did not improve from 0.11396
#
# Epoch 00665: val_loss did not improve from 0.11396
#
# Epoch 00666: val_loss did not improve from 0.11396
#
# Epoch 00667: val_loss did not improve from 0.11396
#
# Epoch 00668: val_loss did not improve from 0.11396
#
# Epoch 00669: val_loss did not improve from 0.11396
#
# Epoch 00670: val_loss did not improve from 0.11396
#
# Epoch 00671: val_loss did not improve from 0.11396
#
# Epoch 00672: val_loss did not improve from 0.11396
#
# Epoch 00673: val_loss did not improve from 0.11396
#
# Epoch 00674: val_loss improved from 0.11396 to 0.11365, saving model to ./model/674-0.1136.hdf5
#
# Epoch 00675: val_loss did not improve from 0.11365
#
# Epoch 00676: val_loss did not improve from 0.11365
#
# Epoch 00677: val_loss did not improve from 0.11365
#
# Epoch 00678: val_loss did not improve from 0.11365
#
# Epoch 00679: val_loss did not improve from 0.11365
#
# Epoch 00680: val_loss did not improve from 0.11365
#
# Epoch 00681: val_loss did not improve from 0.11365
#
# Epoch 00682: val_loss improved from 0.11365 to 0.11355, saving model to ./model/682-0.1136.hdf5
#
# Epoch 00683: val_loss did not improve from 0.11355
#
# Epoch 00684: val_loss did not improve from 0.11355
#
# Epoch 00685: val_loss did not improve from 0.11355
#
# Epoch 00686: val_loss improved from 0.11355 to 0.11264, saving model to ./model/686-0.1126.hdf5
#
# Epoch 00687: val_loss did not improve from 0.11264
#
# Epoch 00688: val_loss did not improve from 0.11264
#
# Epoch 00689: val_loss did not improve from 0.11264
#
# Epoch 00690: val_loss did not improve from 0.11264
#
# Epoch 00691: val_loss did not improve from 0.11264
#
# Epoch 00692: val_loss did not improve from 0.11264
#
# Epoch 00693: val_loss did not improve from 0.11264
#
# Epoch 00694: val_loss improved from 0.11264 to 0.11232, saving model to ./model/694-0.1123.hdf5
#
# Epoch 00695: val_loss did not improve from 0.11232
#
# Epoch 00696: val_loss did not improve from 0.11232
#
# Epoch 00697: val_loss did not improve from 0.11232
#
# Epoch 00698: val_loss did not improve from 0.11232
#
# Epoch 00699: val_loss did not improve from 0.11232
#
# Epoch 00700: val_loss did not improve from 0.11232
#
# Epoch 00701: val_loss did not improve from 0.11232
#
# Epoch 00702: val_loss did not improve from 0.11232
#
# Epoch 00703: val_loss did not improve from 0.11232
#
# Epoch 00704: val_loss did not improve from 0.11232
#
# Epoch 00705: val_loss did not improve from 0.11232
#
# Epoch 00706: val_loss did not improve from 0.11232
#
# Epoch 00707: val_loss did not improve from 0.11232
#
# Epoch 00708: val_loss did not improve from 0.11232
#
# Epoch 00709: val_loss did not improve from 0.11232
#
# Epoch 00710: val_loss did not improve from 0.11232
#
# Epoch 00711: val_loss did not improve from 0.11232
#
# Epoch 00712: val_loss did not improve from 0.11232
#
# Epoch 00713: val_loss did not improve from 0.11232
#
# Epoch 00714: val_loss did not improve from 0.11232
#
# Epoch 00715: val_loss did not improve from 0.11232
#
# Epoch 00716: val_loss did not improve from 0.11232
#
# Epoch 00717: val_loss did not improve from 0.11232
#
# Epoch 00718: val_loss did not improve from 0.11232
#
# Epoch 00719: val_loss did not improve from 0.11232
#
# Epoch 00720: val_loss did not improve from 0.11232
#
# Epoch 00721: val_loss did not improve from 0.11232
#
# Epoch 00722: val_loss did not improve from 0.11232
#
# Epoch 00723: val_loss improved from 0.11232 to 0.11228, saving model to ./model/723-0.1123.hdf5
#
# Epoch 00724: val_loss did not improve from 0.11228
#
# Epoch 00725: val_loss did not improve from 0.11228
#
# Epoch 00726: val_loss did not improve from 0.11228
#
# Epoch 00727: val_loss improved from 0.11228 to 0.11112, saving model to ./model/727-0.1111.hdf5
#
# Epoch 00728: val_loss did not improve from 0.11112
#
# Epoch 00729: val_loss did not improve from 0.11112
#
# Epoch 00730: val_loss did not improve from 0.11112
#
# Epoch 00731: val_loss did not improve from 0.11112
#
# Epoch 00732: val_loss did not improve from 0.11112
#
# Epoch 00733: val_loss did not improve from 0.11112
#
# Epoch 00734: val_loss did not improve from 0.11112
#
# Epoch 00735: val_loss improved from 0.11112 to 0.11053, saving model to ./model/735-0.1105.hdf5
#
# Epoch 00736: val_loss did not improve from 0.11053
#
# Epoch 00737: val_loss did not improve from 0.11053
#
# Epoch 00738: val_loss did not improve from 0.11053
#
# Epoch 00739: val_loss did not improve from 0.11053
#
# Epoch 00740: val_loss did not improve from 0.11053
#
# Epoch 00741: val_loss did not improve from 0.11053
#
# Epoch 00742: val_loss did not improve from 0.11053
#
# Epoch 00743: val_loss did not improve from 0.11053
#
# Epoch 00744: val_loss did not improve from 0.11053
#
# Epoch 00745: val_loss did not improve from 0.11053
#
# Epoch 00746: val_loss did not improve from 0.11053
#
# Epoch 00747: val_loss improved from 0.11053 to 0.11016, saving model to ./model/747-0.1102.hdf5
#
# Epoch 00748: val_loss did not improve from 0.11016
#
# Epoch 00749: val_loss did not improve from 0.11016
#
# Epoch 00750: val_loss did not improve from 0.11016
#
# Epoch 00751: val_loss did not improve from 0.11016
#
# Epoch 00752: val_loss did not improve from 0.11016
#
# Epoch 00753: val_loss did not improve from 0.11016
#
# Epoch 00754: val_loss did not improve from 0.11016
#
# Epoch 00755: val_loss improved from 0.11016 to 0.10932, saving model to ./model/755-0.1093.hdf5
#
# Epoch 00756: val_loss did not improve from 0.10932
#
# Epoch 00757: val_loss did not improve from 0.10932
#
# Epoch 00758: val_loss did not improve from 0.10932
#
# Epoch 00759: val_loss did not improve from 0.10932
#
# Epoch 00760: val_loss did not improve from 0.10932
#
# ...
#
# Epoch 00883: val_loss did not improve from 0.10689
#
# Epoch 00884: val_loss did not improve from 0.10689
#
# Epoch 00885: val_loss did not improve from 0.10689
#
# Epoch 00886: val_loss did not improve from 0.10689
#
# Epoch 00887: val_loss did not improve from 0.10689
#
# Epoch 00888: val_loss did not improve from 0.10689
#
# Epoch 00889: val_loss did not improve from 0.10689
#
# Epoch 00890: val_loss did not improve from 0.10689
#
# Epoch 00891: val_loss did not improve from 0.10689
#
# Epoch 00892: val_loss did not improve from 0.10689
#
# Epoch 00893: val_loss did not improve from 0.10689
#
# Epoch 00894: val_loss improved from 0.10689 to 0.10653, saving model to ./model/894-0.1065.hdf5
#
# Epoch 00895: val_loss did not improve from 0.10653
#
# Epoch 00896: val_loss did not improve from 0.10653
#
# Epoch 00897: val_loss did not improve from 0.10653
#
# Epoch 00898: val_loss did not improve from 0.10653
#
# Epoch 00899: val_loss did not improve from 0.10653
#
# Epoch 00900: val_loss did not improve from 0.10653
#
# Epoch 00901: val_loss did not improve from 0.10653
#
# Epoch 00902: val_loss did not improve from 0.10653
#
# Epoch 00903: val_loss did not improve from 0.10653
#
# Epoch 00904: val_loss did not improve from 0.10653
#
# Epoch 00905: val_loss did not improve from 0.10653
#
# Epoch 00906: val_loss did not improve from 0.10653
#
# Epoch 00907: val_loss did not improve from 0.10653
#
# Epoch 00908: val_loss did not improve from 0.10653
#
# Epoch 00909: val_loss did not improve from 0.10653
#
# Epoch 00910: val_loss did not improve from 0.10653
#
# Epoch 00911: val_loss did not improve from 0.10653
#
# Epoch 00912: val_loss did not improve from 0.10653
#
# Epoch 00913: val_loss did not improve from 0.10653
#
# Epoch 00914: val_loss did not improve from 0.10653
#
# Epoch 00915: val_loss did not improve from 0.10653
#
# Epoch 00916: val_loss did not improve from 0.10653
#
# Epoch 00917: val_loss did not improve from 0.10653
#
# Epoch 00918: val_loss did not improve from 0.10653
#
# Epoch 00919: val_loss did not improve from 0.10653
#
# Epoch 00920: val_loss did not improve from 0.10653
#
# Epoch 00921: val_loss did not improve from 0.10653
#
# Epoch 00922: val_loss did not improve from 0.10653
#
# Epoch 00923: val_loss did not improve from 0.10653
#
# Epoch 00924: val_loss did not improve from 0.10653
#
# Epoch 00925: val_loss did not improve from 0.10653
#
# Epoch 00926: val_loss did not improve from 0.10653
#
# Epoch 00927: val_loss did not improve from 0.10653
#
# Epoch 00928: val_loss did not improve from 0.10653
#
# Epoch 00929: val_loss did not improve from 0.10653
#
# Epoch 00930: val_loss did not improve from 0.10653
#
# Epoch 00931: val_loss did not improve from 0.10653
#
# Epoch 00932: val_loss did not improve from 0.10653
#
# Epoch 00933: val_loss did not improve from 0.10653
#
# Epoch 00934: val_loss did not improve from 0.10653
#
# Epoch 00935: val_loss did not improve from 0.10653
#
# Epoch 00936: val_loss did not improve from 0.10653
#
# Epoch 00937: val_loss did not improve from 0.10653
#
# Epoch 00938: val_loss improved from 0.10653 to 0.10595, saving model to ./model/938-0.1060.hdf5
#
# Epoch 00939: val_loss did not improve from 0.10595
#
# Epoch 00940: val_loss did not improve from 0.10595
#
# Epoch 00941: val_loss did not improve from 0.10595
#
# Epoch 00942: val_loss did not improve from 0.10595
#
# Epoch 00943: val_loss did not improve from 0.10595
#
# Epoch 00944: val_loss did not improve from 0.10595
#
# Epoch 00945: val_loss did not improve from 0.10595
#
# Epoch 00946: val_loss did not improve from 0.10595
#
# Epoch 00947: val_loss did not improve from 0.10595
#
# Epoch 00948: val_loss did not improve from 0.10595
#
# Epoch 00949: val_loss did not improve from 0.10595
#
# Epoch 00950: val_loss did not improve from 0.10595
#
# Epoch 00951: val_loss did not improve from 0.10595
#
# Epoch 00952: val_loss did not improve from 0.10595
#
# Epoch 00953: val_loss did not improve from 0.10595
#
# Epoch 00954: val_loss did not improve from 0.10595
#
# Epoch 00955: val_loss did not improve from 0.10595
#
# Epoch 00956: val_loss did not improve from 0.10595
#
# Epoch 00957: val_loss did not improve from 0.10595
#
# Epoch 00958: val_loss did not improve from 0.10595
#
# Epoch 00959: val_loss did not improve from 0.10595
#
# Epoch 00960: val_loss did not improve from 0.10595
#
# Epoch 00961: val_loss did not improve from 0.10595
#
# Epoch 00962: val_loss did not improve from 0.10595
#
# Epoch 00963: val_loss did not improve from 0.10595
#
# Epoch 00964: val_loss did not improve from 0.10595
# Epoch 00965: val_loss did not improve from 0.10595
#
# Epoch 00966: val_loss did not improve from 0.10595
#
# Epoch 00967: val_loss did not improve from 0.10595
#
# Epoch 00968: val_loss did not improve from 0.10595
#
# Epoch 00969: val_loss did not improve from 0.10595
#
# Epoch 00970: val_loss did not improve from 0.10595
#
# Epoch 00971: val_loss did not improve from 0.10595
#
# Epoch 00972: val_loss did not improve from 0.10595
#
# Epoch 00973: val_loss did not improve from 0.10595
#
# Epoch 00974: val_loss did not improve from 0.10595
#
# Epoch 00975: val_loss did not improve from 0.10595
#
# Epoch 00976: val_loss did not improve from 0.10595
#
# Epoch 00977: val_loss did not improve from 0.10595
#
# Epoch 00978: val_loss did not improve from 0.10595
#
# Epoch 00979: val_loss did not improve from 0.10595
#
# Epoch 00980: val_loss did not improve from 0.10595
#
# Epoch 00981: val_loss did not improve from 0.10595
#
# Epoch 00982: val_loss did not improve from 0.10595
#
# Epoch 00983: val_loss did not improve from 0.10595
#
# Epoch 00984: val_loss did not improve from 0.10595
#
# Epoch 00985: val_loss improved from 0.10595 to 0.10479, saving model to ./model/985-0.1048.hdf5
#
# Epoch 00986: val_loss did not improve from 0.10479
#
# Epoch 00987: val_loss did not improve from 0.10479
#
# Epoch 00988: val_loss did not improve from 0.10479
#
# Epoch 00989: val_loss did not improve from 0.10479
#
# Epoch 00990: val_loss did not improve from 0.10479
#
# Epoch 00991: val_loss did not improve from 0.10479
#
# Epoch 00992: val_loss did not improve from 0.10479
#
# Epoch 00993: val_loss did not improve from 0.10479
#
# Epoch 00994: val_loss did not improve from 0.10479
#
# Epoch 00995: val_loss did not improve from 0.10479
#
# Epoch 00996: val_loss did not improve from 0.10479
#
# Epoch 00997: val_loss did not improve from 0.10479
#
# Epoch 00998: val_loss did not improve from 0.10479
#
# Epoch 00999: val_loss did not improve from 0.10479
#
# Epoch 01000: val_loss did not improve from 0.10479
#
# Epoch 01001: val_loss did not improve from 0.10479
#
# Epoch 01002: val_loss did not improve from 0.10479
#
# Epoch 01003: val_loss did not improve from 0.10479
#
# Epoch 01004: val_loss did not improve from 0.10479
#
# Epoch 01005: val_loss did not improve from 0.10479
#
# Epoch 01006: val_loss did not improve from 0.10479
#
# Epoch 01007: val_loss did not improve from 0.10479
#
# Epoch 01008: val_loss did not improve from 0.10479
#
# Epoch 01009: val_loss did not improve from 0.10479
#
# Epoch 01010: val_loss did not improve from 0.10479
#
# Epoch 01011: val_loss did not improve from 0.10479
#
# Epoch 01012: val_loss did not improve from 0.10479
#
# Epoch 01013: val_loss did not improve from 0.10479
#
# Epoch 01014: val_loss did not improve from 0.10479
#
# Epoch 01015: val_loss did not improve from 0.10479
#
# Epoch 01016: val_loss did not improve from 0.10479
#
# Epoch 01017: val_loss did not improve from 0.10479
#
# Epoch 01018: val_loss did not improve from 0.10479
#
# Epoch 01019: val_loss did not improve from 0.10479
#
# Epoch 01020: val_loss did not improve from 0.10479
#
# Epoch 01021: val_loss did not improve from 0.10479
#
# Epoch 01022: val_loss did not improve from 0.10479
#
# Epoch 01023: val_loss did not improve from 0.10479
#
# Epoch 01024: val_loss did not improve from 0.10479
#
# Epoch 01025: val_loss did not improve from 0.10479
#
# Epoch 01026: val_loss did not improve from 0.10479
#
# Epoch 01027: val_loss did not improve from 0.10479
#
# Epoch 01028: val_loss did not improve from 0.10479
#
# Epoch 01029: val_loss did not improve from 0.10479
#
# Epoch 01030: val_loss did not improve from 0.10479
#
# Epoch 01031: val_loss did not improve from 0.10479
#
# Epoch 01032: val_loss improved from 0.10479 to 0.10398, saving model to ./model/1032-0.1040.hdf5
#
# Epoch 01033: val_loss did not improve from 0.10398
#
# Epoch 01034: val_loss did not improve from 0.10398
#
# Epoch 01035: val_loss did not improve from 0.10398
#
# Epoch 01036: val_loss did not improve from 0.10398
#
# Epoch 01037: val_loss did not improve from 0.10398
#
# Epoch 01038: val_loss did not improve from 0.10398
#
# Epoch 01039: val_loss did not improve from 0.10398
#
# Epoch 01040: val_loss did not improve from 0.10398
#
# Epoch 01041: val_loss did not improve from 0.10398
#
# Epoch 01042: val_loss did not improve from 0.10398
#
# Epoch 01043: val_loss did not improve from 0.10398
#
# Epoch 01044: val_loss did not improve from 0.10398
#
# Epoch 01045: val_loss did not improve from 0.10398
#
# Epoch 01046: val_loss did not improve from 0.10398
#
# Epoch 01047: val_loss did not improve from 0.10398
#
# Epoch 01048: val_loss did not improve from 0.10398
#
# Epoch 01049: val_loss did not improve from 0.10398
#
# Epoch 01050: val_loss did not improve from 0.10398
#
# Epoch 01051: val_loss did not improve from 0.10398
#
# Epoch 01052: val_loss did not improve from 0.10398
#
# Epoch 01053: val_loss did not improve from 0.10398
#
# Epoch 01054: val_loss did not improve from 0.10398
#
# Epoch 01055: val_loss did not improve from 0.10398
#
# Epoch 01056: val_loss did not improve from 0.10398
#
# Epoch 01057: val_loss did not improve from 0.10398
#
# Epoch 01058: val_loss did not improve from 0.10398
#
# Epoch 01059: val_loss did not improve from 0.10398
#
# Epoch 01060: val_loss did not improve from 0.10398
#
# Epoch 01061: val_loss did not improve from 0.10398
#
# Epoch 01062: val_loss did not improve from 0.10398
#
# Epoch 01063: val_loss did not improve from 0.10398
#
# Epoch 01064: val_loss did not improve from 0.10398
#
# Epoch 01065: val_loss did not improve from 0.10398
#
# Epoch 01066: val_loss did not improve from 0.10398
#
# Epoch 01067: val_loss did not improve from 0.10398
#
# Epoch 01068: val_loss did not improve from 0.10398
#
# Epoch 01069: val_loss did not improve from 0.10398
#
# Epoch 01070: val_loss did not improve from 0.10398
#
# Epoch 01071: val_loss did not improve from 0.10398
#
# Epoch 01072: val_loss did not improve from 0.10398
#
# Epoch 01073: val_loss did not improve from 0.10398
#
# Epoch 01074: val_loss did not improve from 0.10398
#
# Epoch 01075: val_loss did not improve from 0.10398
#
# Epoch 01076: val_loss did not improve from 0.10398
#
# Epoch 01077: val_loss did not improve from 0.10398
#
# Epoch 01078: val_loss did not improve from 0.10398
#
# Epoch 01079: val_loss did not improve from 0.10398
#
# Epoch 01080: val_loss did not improve from 0.10398
#
# Epoch 01081: val_loss did not improve from 0.10398
#
# Epoch 01082: val_loss did not improve from 0.10398
#
# Epoch 01083: val_loss did not improve from 0.10398
#
# Epoch 01084: val_loss did not improve from 0.10398
#
# Epoch 01085: val_loss improved from 0.10398 to 0.10303, saving model to ./model/1085-0.1030.hdf5
#
# Epoch 01086: val_loss did not improve from 0.10303
#
# Epoch 01087: val_loss did not improve from 0.10303
#
# Epoch 01088: val_loss did not improve from 0.10303
#
# Epoch 01089: val_loss did not improve from 0.10303
#
# Epoch 01090: val_loss did not improve from 0.10303
#
# Epoch 01091: val_loss did not improve from 0.10303
#
# Epoch 01092: val_loss did not improve from 0.10303
#
# Epoch 01093: val_loss did not improve from 0.10303
#
# Epoch 01094: val_loss did not improve from 0.10303
#
# Epoch 01095: val_loss did not improve from 0.10303
#
# Epoch 01096: val_loss did not improve from 0.10303
#
# Epoch 01097: val_loss did not improve from 0.10303
#
# Epoch 01098: val_loss did not improve from 0.10303
#
# Epoch 01099: val_loss did not improve from 0.10303
#
# Epoch 01100: val_loss did not improve from 0.10303
#
# Epoch 01101: val_loss did not improve from 0.10303
#
# Epoch 01102: val_loss did not improve from 0.10303
#
# Epoch 01103: val_loss did not improve from 0.10303
#
# Epoch 01104: val_loss did not improve from 0.10303
#
# Epoch 01105: val_loss did not improve from 0.10303
#
# Epoch 01106: val_loss did not improve from 0.10303
#
# Epoch 01107: val_loss did not improve from 0.10303
#
# Epoch 01108: val_loss did not improve from 0.10303
#
# Epoch 01109: val_loss did not improve from 0.10303
#
# Epoch 01110: val_loss did not improve from 0.10303
#
# Epoch 01111: val_loss did not improve from 0.10303
#
# Epoch 01112: val_loss did not improve from 0.10303
#
# Epoch 01113: val_loss did not improve from 0.10303
#
# Epoch 01114: val_loss did not improve from 0.10303
#
# Epoch 01115: val_loss did not improve from 0.10303
#
# Epoch 01116: val_loss did not improve from 0.10303
#
# Epoch 01117: val_loss did not improve from 0.10303
#
# Epoch 01118: val_loss did not improve from 0.10303
# Epoch 01119: val_loss did not improve from 0.10303
#
# Epoch 01120: val_loss did not improve from 0.10303
#
# Epoch 01121: val_loss did not improve from 0.10303
#
# Epoch 01122: val_loss did not improve from 0.10303
#
# Epoch 01123: val_loss did not improve from 0.10303
#
# Epoch 01124: val_loss did not improve from 0.10303
#
# Epoch 01125: val_loss did not improve from 0.10303
#
# Epoch 01126: val_loss did not improve from 0.10303
#
# Epoch 01127: val_loss did not improve from 0.10303
#
# Epoch 01128: val_loss did not improve from 0.10303
#
# Epoch 01129: val_loss did not improve from 0.10303
#
# Epoch 01130: val_loss did not improve from 0.10303
#
# Epoch 01131: val_loss did not improve from 0.10303
#
# Epoch 01132: val_loss did not improve from 0.10303
#
# Epoch 01133: val_loss did not improve from 0.10303
#
# Epoch 01134: val_loss did not improve from 0.10303
#
# Epoch 01135: val_loss did not improve from 0.10303
#
# Epoch 01136: val_loss did not improve from 0.10303
#
# Epoch 01137: val_loss did not improve from 0.10303
#
# Epoch 01138: val_loss did not improve from 0.10303
#
# Epoch 01139: val_loss did not improve from 0.10303
#
# Epoch 01140: val_loss did not improve from 0.10303
#
# Epoch 01141: val_loss did not improve from 0.10303
#
# Epoch 01142: val_loss did not improve from 0.10303
#
# Epoch 01143: val_loss did not improve from 0.10303
#
# Epoch 01144: val_loss did not improve from 0.10303
#
# Epoch 01145: val_loss did not improve from 0.10303
#
# Epoch 01146: val_loss did not improve from 0.10303
#
# Epoch 01147: val_loss did not improve from 0.10303
#
# Epoch 01148: val_loss did not improve from 0.10303
#
# Epoch 01149: val_loss did not improve from 0.10303
#
# Epoch 01150: val_loss did not improve from 0.10303
#
# Epoch 01151: val_loss did not improve from 0.10303
#
# Epoch 01152: val_loss did not improve from 0.10303
#
# Epoch 01153: val_loss did not improve from 0.10303
#
# Epoch 01154: val_loss did not improve from 0.10303
#
# Epoch 01155: val_loss did not improve from 0.10303
#
# Epoch 01156: val_loss did not improve from 0.10303
#
# Epoch 01157: val_loss did not improve from 0.10303
#
# Epoch 01158: val_loss did not improve from 0.10303
#
# Epoch 01159: val_loss did not improve from 0.10303
#
# Epoch 01160: val_loss did not improve from 0.10303
#
# Epoch 01161: val_loss did not improve from 0.10303
#
# Epoch 01162: val_loss did not improve from 0.10303
#
# Epoch 01163: val_loss did not improve from 0.10303
#
# Epoch 01164: val_loss did not improve from 0.10303
#
# Epoch 01165: val_loss did not improve from 0.10303
#
# Epoch 01166: val_loss did not improve from 0.10303
#
# Epoch 01167: val_loss did not improve from 0.10303
#
# Epoch 01168: val_loss did not improve from 0.10303
#
# Epoch 01169: val_loss did not improve from 0.10303
#
# Epoch 01170: val_loss did not improve from 0.10303
#
# Epoch 01171: val_loss did not improve from 0.10303
#
# Epoch 01172: val_loss did not improve from 0.10303
#
# Epoch 01173: val_loss did not improve from 0.10303
#
# Epoch 01174: val_loss did not improve from 0.10303
#
# Epoch 01175: val_loss did not improve from 0.10303
#
# Epoch 01176: val_loss did not improve from 0.10303
#
# Epoch 01177: val_loss did not improve from 0.10303
#
# Epoch 01178: val_loss did not improve from 0.10303
#
# Epoch 01179: val_loss did not improve from 0.10303
#
# Epoch 01180: val_loss did not improve from 0.10303
#
# Epoch 01181: val_loss did not improve from 0.10303
#
# Epoch 01182: val_loss did not improve from 0.10303
#
# Epoch 01183: val_loss did not improve from 0.10303
#
# Epoch 01184: val_loss did not improve from 0.10303
#
# Epoch 01185: val_loss did not improve from 0.10303
